# %% [markdown]
# # Series Data Frame Pandas

# %% [markdown]
# Importar libreria

# %%
import pandas as pd
import numpy as np

# %%
psg_players = pd.Series(["Navas","Mbappe",'Neymar',"Messi"], 
          index = [1,7,10,30] )
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players = pd.Series(["Navas","Mbappe",'Neymar',"Messi"]) #sin indice
psg_players
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %%
dict = {1: 'Navas',7: 'Mbappe', 10: 'Neymar', 30: "Messi"}
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[0:3]
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# dtype: object

# %%
dict = {"jugador": ["Navas","Mbappe",'Neymar',"Messi"],
 "Altura" : [183,170,173,165],
 "Goles"  : [2,200,300,100]}

df_player = pd.DataFrame(dict, index=[1,7,10,30] )
df_player
# Out:
#    jugador  Altura  Goles
# 1    Navas     183      2
# 7   Mbappe     170    200
# 10  Neymar     173    300
# 30   Messi     165    100

# %%
print(df_player.columns)
print(df_player.index)
# Out:
# Index(['jugador', 'Altura', 'Goles'], dtype='object')
# Index([1, 7, 10, 30], dtype='int64')

# %% [markdown]
# ## Importar datos

# %%
df_books = pd.read_csv("C:/Users/User/Desktop/Productivo/Platzi/Manipulacion y transformacion datos Pandas y Numpy/Codigo/Bestsellers-with-categories.csv", sep=","
                  , header=0) # sep indica como se separa los datos, header indica en que posicicon esta las columnas, names para cambiar de nombre los headers (se pasa una lista)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_characters = pd.read_json("C:/Users/User/Desktop/Productivo/Platzi/Manipulacion y transformacion datos Pandas y Numpy/Codigo/HPCharacterDataRaw.Json")
df_characters
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
df_books[0:4]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
df_books[['Name','Author','Year']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Year
# 0                    JJ Smith  2016
# 1                Stephen King  2011
# 2          Jordan B. Peterson  2018
# 3               George Orwell  2017
# 4    National Geographic Kids  2019
# ..                        ...   ...
# 545               Jeff Kinney  2019
# ...

# %% [markdown]
# ## Filtrado con Loc y Iloc

# %% [markdown]
# loc

# %%
df_books.loc[:4, ['Name','Author']] # Este si incluye el stop
# Out:
#                                                 Name                    Author
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
df_books.loc[:, ['Reviews']] * -1
# Out:
#      Reviews
# 0     -17350
# 1      -2052
# 2     -18979
# 3     -21424
# 4      -7665
# ..       ...
# 545    -9413
# 546   -14331
# 547   -14331
# 548   -14331
# 549   -14331
#
# [550 rows x 1 columns]

# %%
df_books.loc[:, ['Author']] == "JJ Smith"
# Out:
#      Author
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %% [markdown]
# iloc

# %%
df_books.iloc[:] #iloc trabaja con los indices de las columnas
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.iloc[:,0:3]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ...

# %%
df_books.iloc[1,3] * -1
# Out:
# -2052

# %%
df_books.iloc[:2,2:]
# Out:
#    User Rating  Reviews  Price  Year        Genre
# 0          4.7    17350      8  2016  Non Fiction
# 1          4.6     2052     22  2011      Fiction

# %% [markdown]
# ## Agregar o eliminar datos

# %% [markdown]
# drops columsn

# %%
df_books.drop('Genre',axis=1).head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books.head(2) #.drop no reemplaza el dataframe original
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.drop('Genre',axis=1, inplace=True)
#inplace= True dropea o elimina y reemplaza la original
#

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books = df_books.drop('Year', axis=1) #otra manera de eliminar permanentemente
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %%
del df_books['Price'] # Otra manera de eliminar permanentemente
print(df_books.head(2))
# Out:
#                             Name        Author  User Rating  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350
# 1              11/22/63: A Novel  Stephen King          4.6     2052

# %% [markdown]
# Drop rows

# %%
#Importar denuevo
df_books = pd.read_csv("C:/Users/User/Desktop/Productivo/Platzi/Manipulacion y transformacion datos Pandas y Numpy/Codigo/Bestsellers-with-categories.csv", sep=","
                  , header=0) # sep indica como se separa los datos, header indica en que posicicon esta las columnas, names para cambiar de nombre los headers (se pasa una lista)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.drop(0, axis=0).head(2) #elimina la primera entrada(0)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df_books.drop([0,1,2], axis=0).head(2) #eliminar una serie de entradas
# Out:
#                                                 Name  \
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.drop(range(0,10), axis=0).head(2) #elimina un rango de entradas
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Price  Year        Genre
# 10          4.6    23848      8  2017      Fiction
# 11          4.6      460      2  2010  Non Fiction

# %% [markdown]
# Para eliminar entradas permanentementes se hace de las 3 maneras ya vistas:
# inplace = True, reemplazar variable o con del

# %% [markdown]
# ### Agregar columnas

# %%
df_books["Nueva columna"] = np.nan
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva columna
# 0  2016  Non Fiction            NaN
# 1  2011      Fiction            NaN

# %%
datos = np.arange(0,df_books.shape[0])
# .shape[0] muestra la cantidad de registros, .shape[1] la cantidad de columnas
# se crea un array del rango desde 0 hasta la cantidad total de registros

# %%
df_books["Rango"] = datos
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ### Agregar registros o filas

# %%
df_books = pd.concat([df_books,df_books]) 
#en este caso concat concatena dos o mas dataframes
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# # Manejo de datos nulos

# %%
dict = {"Col1": [1,2,3,np.nan],
 "Col2": [4,np.nan,6,7],
 "Col3": ["a","b","c", None]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %%
df.isnull() # devuelve un df booleano donde True es donde hay nulos
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %%
df.isnull()*1 # Devuelve un df donde 1 es true, 0 false
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %%
df.fillna("Missing") #reemplaza los na por la entrada
# Out:
#       Col1     Col2     Col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %%
df.interpolate() # rellena los datos nulos por interpolacion

# %%
df.dropna() #elimina los registros que contengan algun valor nulo
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# ## Filtrado por Condiciones

# %%
#Importar denuevo
df_books = pd.read_csv("C:/Users/User/Desktop/Productivo/Platzi/Manipulacion y transformacion datos Pandas y Numpy/Codigo/Bestsellers-with-categories.csv", sep=","
                  , header=0) # sep indica como se separa los datos, header indica en que posicicon esta las columnas, names para cambiar de nombre los headers (se pasa una lista)
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
mayor16  = df_books["Year"] >2016 # Devuelve una serie de booleanos
mayor16
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 545     True
# 546    False
# 547     True
# 548     True
# 549     True
# Name: Year, Length: 550, dtype: bool

# %%
df_books[mayor16]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
genre_Fiction = df_books["Genre" ] == "Fiction"
genre_Fiction
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 545     True
# 546    False
# 547    False
# 548    False
# 549    False
# Name: Genre, Length: 550, dtype: bool

# %%
df_books[genre_Fiction & mayor16]
# Out:
#                                                   Name             Author  \
# 3                               1984 (Signet Classics)      George Orwell
# 7                       A Gentleman in Moscow: A Novel        Amor Towles
# 10                           A Man Called Ove: A Novel    Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?    Bill Martin Jr.
# ..                                                 ...                ...
# 509                              To Kill a Mockingbird         Harper Lee
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 534                            Where the Crawdads Sing        Delia Owens
# 544                                             Wonder      R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)        Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
df_books[~genre_Fiction & mayor16] # ~ niega la proposicion
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 26                  Astrophysics for People in a Hurry
# 32                                            Becoming
# ..                                                 ...
# 526                                      What Happened
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 2                  Jordan B. Peterson          4.7    18979     15  2018
# 4            National Geographic Kids          4.8     7665     12  2019
# 8                         James Comey          4.7     5983      3  2018
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones principales

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df_books.describe() # presenta algunas informaciones de estadistica descriptiva
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df_books.head(2) # devuelve los n primeros registros
df_books.tail(2) # devuelve los n ultimos registros
# Out:
#                                                   Name       Author  \
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
df_books.memory_usage(deep=True) # menciona por columnas su uso de memoria
# Out:
# Index            132
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %%
df_books["Author"].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %%
df_books.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
df_books = pd.concat([df_books,df_books.iloc[0]], axis=0) #duplicamos el primer registro
df_books
# Out:
#                                                       Name  \
# 0                            10-Day Green Smoothie Cleanse
# 1                                        11/22/63: A Novel
# 2                  12 Rules for Life: An Antidote to Chaos
# 3                                   1984 (Signet Classics)
# 4        5,000 Awesome Facts (About Everything!) (Natio...
# ...                                                    ...
# Reviews                                                NaN
# Price                                                  NaN
# Year                                                   NaN
# Genre                                                  NaN
# 0                                                      NaN
#
#                            Author  User Rating  Reviews  Price    Year  \
# 0                        JJ Smith          4.7  17350.0    8.0  2016.0
# 1                    Stephen King          4.6   2052.0   22.0  2011.0
# ...

# %%
df_books.tail()
# Out:
#             Name Author  User Rating  Reviews  Price  Year Genre            0
# User Rating  NaN    NaN          NaN      NaN    NaN   NaN   NaN          4.7
# Reviews      NaN    NaN          NaN      NaN    NaN   NaN   NaN        17350
# Price        NaN    NaN          NaN      NaN    NaN   NaN   NaN            8
# Year         NaN    NaN          NaN      NaN    NaN   NaN   NaN         2016
# Genre        NaN    NaN          NaN      NaN    NaN   NaN   NaN  Non Fiction

# %%
df_books.drop_duplicates() # Elimina los duplicados

# %%
df_books.sort_values("Year" , ascending=False) #Ordena segun una columna
# ascending = False para que sea mayor a menor
# Out:
#                                                       Name  \
# 549      You Are a Badass: How to Stop Doubting Your Gr...
# 294      School Zone - Big Preschool Workbook - Ages 4 ...
# 489                       The Wonderful Things You Will Be
# 263        P is for Potty! (Sesame Street) (Lift-the-Flap)
# 130      Girl, Wash Your Face: Stop Believing the Lies ...
# ...                                                    ...
# Reviews                                                NaN
# Price                                                  NaN
# Year                                                   NaN
# Genre                                                  NaN
# 0                                                      NaN
#
#                         Author  User Rating  Reviews  Price    Year  \
# 549                Jen Sincero          4.7  14331.0    8.0  2019.0
# 294                School Zone          4.8  23047.0    6.0  2019.0
# ...

# %% [markdown]
# ## Group by

# %%
df_books.groupby("Author").count() # cuantos registros por author
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre  0
# Author
# Abraham Verghese               2            2        2      2     2      2  0
# Adam Gasiewski                 1            1        1      1     1      1  0
# Adam Mansbach                  1            1        1      1     1      1  0
# Adir Levy                      1            1        1      1     1      1  0
# Admiral William H. McRaven     1            1        1      1     1      1  0
# ...                          ...          ...      ...    ...   ...    ... ..
# Walter Isaacson                3            3        3      3     3      3  0
# William Davis                  2            2        2      2     2      2  0
# William P. Young               2            2        2      2     2      2  0
# Wizards RPG Team               3            3        3      3     3      3  0
# Zhi Gang Sha                   2            2        2      2     2      2  0
#
# [248 rows x 7 columns]

# %%
df_books.groupby("Author").sum().loc["William Davis"] 
# en group by, la entrada que elegimos se vuelve el indice
# Out:
# Name           Wheat Belly: Lose the Wheat, Lose the Weight, ...
# User Rating                                                  8.8
# Reviews                                                  14994.0
# Price                                                       12.0
# Year                                                      4025.0
# Genre                                     Non FictionNon Fiction
# 0                                                              0
# Name: William Davis, dtype: object

# %%
df_books.groupby("Author").agg(["min","max"])
# .agg para dar varias funciones
# Out:
#                                                                          Name  \
#                                                                           min
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# ...

# %%
df_books.groupby("Author").agg({"Reviews":["min","max"] ,"User Rating": "sum"})
# Especificar mas a traves de diccionarios
# Out:
#                             Reviews          User Rating
#                                 min      max         sum
# Author
# Abraham Verghese             4866.0   4866.0         9.2
# Adam Gasiewski               3113.0   3113.0         4.4
# Adam Mansbach                9568.0   9568.0         4.8
# Adir Levy                    8170.0   8170.0         4.8
# Admiral William H. McRaven  10199.0  10199.0         4.7
# ...                             ...      ...         ...
# Walter Isaacson              3014.0   7827.0        13.7
# William Davis                7497.0   7497.0         8.8
# William P. Young            19720.0  19720.0         9.2
# Wizards RPG Team            16990.0  16990.0        14.4
# Zhi Gang Sha                   37.0    220.0         9.2
#
# [248 rows x 3 columns]

# %%
df_books.groupby(["Author","Year"]).count() #Para dar una llave compuesta
# Out:
#                          Name  User Rating  Reviews  Price  Genre  0
# Author           Year
# Abraham Verghese 2010.0     1            1        1      1      1  0
#                  2011.0     1            1        1      1      1  0
# Adam Gasiewski   2017.0     1            1        1      1      1  0
# Adam Mansbach    2011.0     1            1        1      1      1  0
# Adir Levy        2019.0     1            1        1      1      1  0
# ...                       ...          ...      ...    ...    ... ..
# Wizards RPG Team 2017.0     1            1        1      1      1  0
#                  2018.0     1            1        1      1      1  0
#                  2019.0     1            1        1      1      1  0
# Zhi Gang Sha     2009.0     1            1        1      1      1  0
#                  2013.0     1            1        1      1      1  0
#
# [493 rows x 6 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Combinando dataframes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Merge y concat

# %%
df1 = pd.DataFrame({"A": ["a0","a1","a2","a3"],
         "B": ["b0","b1","b2","b3"],
         "C": ["c0","c1","c2","c3"],
         "D": ["d0","d1","d2","d3"],})

df2 = pd.DataFrame({"A": ["a4","a5","a6","a7"],
         "B": ["b4","b5","b6","b7"],
         "C": ["c4","c5","c6","c7"],
         "D": ["d4","d5","d6","d7"],})

# %%
pd.concat([df1,df2],ignore_index=True) 
# ignore_index = True reordena los indices segun la entrada
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6
# 7  a7  b7  c7  d7

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   D   A   B   C   D
# 0  a0  b0  c0  d0  a4  b4  c4  d4
# 1  a1  b1  c1  d1  a5  b5  c5  d5
# 2  a2  b2  c2  d2  a6  b6  c6  d6
# 3  a3  b3  c3  d3  a7  b7  c7  d7

# %% [markdown]
# Merge

# %%
izq = pd.DataFrame({"key": ["k0","k1","k2","k3"],
    "A": ["a0","a1","a2","a3"],
    "B": ["b0","b1","b2","b3"]})
der = pd.DataFrame({"key": ["k0","k1","k2","k3"],
    "C": ["c0","c1","c2","c3"],
    "D": ["d0","d1","d2","d3"]})

# %%
izq.merge(der , on="key") 
# on = n Hace el merge con una llave en comun, parecido al join de SQL
# Out:
#   key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k1  a1  b1  c1  d1
# 2  k2  a2  b2  c2  d2
# 3  k3  a3  b3  c3  d3

# %%
izq = pd.DataFrame({"key": ["k0","k1","k2","k3"],
    "A": ["a0","a1","a2","a3"],
    "B": ["b0","b1","b2","b3"]})
der = pd.DataFrame({"key2": ["k0","k1","k2","k3"],
    "C": ["c0","c1","c2","c3"],
    "D": ["d0","d1","d2","d3"]})

# %%
izq.merge(der , left_on="key", right_on="key2")
# en caso de que las que hagamos merge no coincidan en el nombre
# Out:
#   key   A   B key2   C   D
# 0  k0  a0  b0   k0  c0  d0
# 1  k1  a1  b1   k1  c1  d1
# 2  k2  a2  b2   k2  c2  d2
# 3  k3  a3  b3   k3  c3  d3

# %%
izq = pd.DataFrame({"key": ["k0","k1","k2","k3"],
    "A": ["a0","a1","a2","a3"],
    "B": ["b0","b1","b2","b3"]})
der = pd.DataFrame({"key2": ["k0","k1","k2",np.nan],
    "C": ["c0","c1","c2","c3"],
    "D": ["d0","d1","d2","d3"]})

# %%
izq.merge(der , left_on="key", right_on="key2", how="right")
# how = "right", "left", "inner" , "outer"
# para hacer los distintos tipos de joins
# Out:
#    key    A    B key2   C   D
# 0   k0   a0   b0   k0  c0  d0
# 1   k1   a1   b1   k1  c1  d1
# 2   k2   a2   b2   k2  c2  d2
# 3  NaN  NaN  NaN  NaN  c3  d3

# %% [markdown]
# # Join

# %% [markdown]
# Join trabaja con los indices en vez de las columnas  como hace el merge
# index match

# %%
izq= pd.DataFrame({"A": ["a0","a1","a2"],
                 "B": ["b0","b1","b2"]},
                 index=["k0",'k1',"k2"])
der= pd.DataFrame({"C": ["c0","c1","c2"],
                   "D": ["d0","d1","d2"]},
                 index=["k0",'k2',"k3"])

# %%
izq.join(der, how="inner")
# Out:
#      A   B   C   D
# k0  a0  b0  c0  d0
# k2  a2  b2  c1  d1

# %%
izq.join(der, how="outer")
# Out:
#       A    B    C    D
# k0   a0   b0   c0   d0
# k1   a1   b1  NaN  NaN
# k2   a2   b2   c1   d1
# k3  NaN  NaN   c2   d2

# %% [markdown]
# ## Pivot table

# %%
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price    Year        Genre  \
# 0                  JJ Smith          4.7  17350.0    8.0  2016.0  Non Fiction
# 1              Stephen King          4.6   2052.0   22.0  2011.0      Fiction
# 2        Jordan B. Peterson          4.7  18979.0   15.0  2018.0  Non Fiction
# 3             George Orwell          4.7  21424.0    6.0  2017.0      Fiction
# 4  National Geographic Kids          4.8   7665.0   12.0  2019.0  Non Fiction
#
#      0
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df_books.pivot_table(index="Author", columns= "Genre", values="User Rating")
# Out:
# Genre                       Fiction  Non Fiction
# Author
# Abraham Verghese                4.6          NaN
# Adam Gasiewski                  NaN     4.400000
# Adam Mansbach                   4.8          NaN
# Adir Levy                       4.8          NaN
# Admiral William H. McRaven      NaN     4.700000
# ...                             ...          ...
# Walter Isaacson                 NaN     4.566667
# William Davis                   NaN     4.400000
# William P. Young                4.6          NaN
# Wizards RPG Team                4.8          NaN
# Zhi Gang Sha                    NaN     4.600000
#
# [248 rows x 2 columns]

# %%
df_books.pivot_table(index="Genre", columns= "Year", values="User Rating", aggfunc="sum")
# Out:
# Year         2009.0  2010.0  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0  \
# Genre
# Fiction       110.2    92.3    97.0    94.4   109.1   134.3    79.1    89.6
# Non Fiction   119.0   135.6   130.9   132.2   118.6    96.8   153.3   144.3
#
# Year         2017.0  2018.0  2019.0
# Genre
# Fiction       113.7    99.5    96.4
# Non Fiction   119.3   133.9   140.6

# %% [markdown]
# ## Melt

# %%
df_books[['Name','Genre']].head(5)
# Out:
#                                                 Name        Genre
# 0                      10-Day Green Smoothie Cleanse  Non Fiction
# 1                                  11/22/63: A Novel      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  Non Fiction
# 3                             1984 (Signet Classics)      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  Non Fiction

# %%
df_books[['Name','Genre']].head(5).melt()
# Out:
#   variable                                              value
# 0     Name                      10-Day Green Smoothie Cleanse
# 1     Name                                  11/22/63: A Novel
# 2     Name            12 Rules for Life: An Antidote to Chaos
# 3     Name                             1984 (Signet Classics)
# 4     Name  5,000 Awesome Facts (About Everything!) (Natio...
# 5    Genre                                        Non Fiction
# 6    Genre                                            Fiction
# 7    Genre                                        Non Fiction
# 8    Genre                                            Fiction
# 9    Genre                                        Non Fiction

# %%
df_books.melt(id_vars='Year',value_vars='Genre').head()
# Out:
#      Year variable        value
# 0  2016.0    Genre  Non Fiction
# 1  2011.0    Genre      Fiction
# 2  2018.0    Genre  Non Fiction
# 3  2017.0    Genre      Fiction
# 4  2019.0    Genre  Non Fiction

# %% [markdown]
# # Apply

# %%
def two_times(value):
    return value*2

# %%
df_books["rating 2"] = df_books["User Rating"].apply(two_times)
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price    Year        Genre  \
# 0                  JJ Smith          4.7  17350.0    8.0  2016.0  Non Fiction
# 1              Stephen King          4.6   2052.0   22.0  2011.0      Fiction
# 2        Jordan B. Peterson          4.7  18979.0   15.0  2018.0  Non Fiction
# 3             George Orwell          4.7  21424.0    6.0  2017.0      Fiction
# 4  National Geographic Kids          4.8   7665.0   12.0  2019.0  Non Fiction
#
#      0  rating 2
# 0  NaN       9.4
# 1  NaN       9.2
# 2  NaN       9.4
# 3  NaN       9.4
# 4  NaN       9.6

# %%
df_books["rating 2"] = df_books["User Rating"].apply(lambda x: x*3)
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price    Year        Genre  \
# 0                  JJ Smith          4.7  17350.0    8.0  2016.0  Non Fiction
# 1              Stephen King          4.6   2052.0   22.0  2011.0      Fiction
# 2        Jordan B. Peterson          4.7  18979.0   15.0  2018.0  Non Fiction
# 3             George Orwell          4.7  21424.0    6.0  2017.0      Fiction
# 4  National Geographic Kids          4.8   7665.0   12.0  2019.0  Non Fiction
#
#      0  rating 2
# 0  NaN      14.1
# 1  NaN      13.8
# 2  NaN      14.1
# 3  NaN      14.1
# 4  NaN      14.4

# %%
df_books["rating 2"] = df_books.apply(lambda x: x["User Rating"] * 2 if x["Genre"] == "Fiction" else x["User Rating"], axis =1)
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price    Year        Genre  \
# 0                  JJ Smith          4.7  17350.0    8.0  2016.0  Non Fiction
# 1              Stephen King          4.6   2052.0   22.0  2011.0      Fiction
# 2        Jordan B. Peterson          4.7  18979.0   15.0  2018.0  Non Fiction
# 3             George Orwell          4.7  21424.0    6.0  2017.0      Fiction
# 4  National Geographic Kids          4.8   7665.0   12.0  2019.0  Non Fiction
#
#      0  rating 2
# 0  NaN       4.7
# 1  NaN       9.2
# 2  NaN       4.7
# 3  NaN       9.4
# 4  NaN       4.8

# %% [markdown]
# ![image.png](attachment:image.png)
